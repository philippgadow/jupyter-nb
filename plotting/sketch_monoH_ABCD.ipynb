# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.xkcd()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
# ax.spines['right'].set_color('none')
# ax.spines['top'].set_color('none')
plt.xticks([])
plt.yticks([])
ax.set_ylim([0, 60])

Z = np.random.rand(60, 100)
c = plt.pcolor(Z, cmap='viridis')

data = 16* np.ones(100)
plt.plot(data)
plt.axvline(x=15)
plt.xlabel('Object based $E_{T}^{miss}$ significance')
plt.ylabel('min ($\Delta \varphi$(jets$_{1,2,3}$, $E_{T}^{miss}$)')
plt.show()
