# %% [markdown]
# ## Check effect of tight jet cleaning on signals

# %% [markdown]
# We noticed a weird met phi distribution with peaks at 0 and at +/- π. This is typical for non-collision background. Previously our cuts on METtrack > 30 GeV in 0 and 1 b-tag regions removed that, but we removed those cuts.
#
# Now we are testing if tight jet cleaning can remedy the situation.
# It can.
#
# However it remains to check the signal efficiency with this additional requirement and verify that it does not get compromised. The efficiency numbers in the following represent integer event counts without any weights applied.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import io

# %%
data_zp2hdm = """
mzp,ma,eff
2600,300,0.980177244635
2000,600,0.991304319281
1200,500,0.991365281463
2400,600,0.991460252112
1800,800,0.98617483074
600,300,0.989621838358
2000,500,0.992361611528
2000,400,0.987080747568
3000,200,0.957353934147
1800,500,0.986764354569
3000,300,1.0
1200,600,0.99279421618
2800,600,0.979160630775
1600,800,0.99079355307
2800,500,1.0
2200,300,0.99140049377
1800,700,0.98951710921
800,500,0.98990641755
2000,800,0.9938475692
2800,300,0.956170946441
2200,400,1.0
2000,700,0.983220412767
1600,600,0.99072731623
2400,700,0.985549788318
1400,700,0.990615939741
1000,600,0.988693585912
1200,700,0.99024050762
1000,400,0.989826041922
2800,400,0.955409791107
2600,600,1.0
3000,500,1.0
1400,500,0.99115683716
600,400,0.984902451429
1600,500,0.993948279726
1400,600,0.987852155268
400,400,0.988645748458
400,300,0.988551644704
2200,700,0.973535444245
2600,700,1.0
1400,800,0.992513260574
2200,600,0.986881147213
800,300,0.991195422689
2200,500,0.991332374376
2400,400,0.993086077066
2600,400,1.0
2600,500,0.983737554018
1000,500,0.993008686226
3000,600,1.0
"""

# %%
data_2hdma_tb10 = """
mA,ma,eff
1100,250,1.0
1200,350,0.988778032895
1400,150,0.992904596371
800,500,0.998985379758
1600,250,0.992006510326
1000,150,1.0
1300,500,1.0
1600,350,0.994579190208
600,350,0.993639258882
1800,150,1.0
"""

# %%
data_2hdma_tb1 = """
mA,ma,eff
1300,500,1.0
1800,150,0.995297879892
600,350,0.991873108465
1100,250,0.987289400582
1600,350,1.0
800,500,0.99855012261
1000,150,1.0
300,150,1.0
1200,350,1.0
1600,250,0.996790451445
"""

# %%
# read the data as a dataframe and check first columns
df_zp2hdm = pd.read_csv(io.StringIO(data_zp2hdm), encoding='utf8', sep=",")
df_zp2hdm.head()
# Out:
#     mzp   ma       eff
# 0  2600  300  0.980177
# 1  2000  600  0.991304
# 2  1200  500  0.991365
# 3  2400  600  0.991460
# 4  1800  800  0.986175

# %%
# read the data as a dataframe and check first columns
df_2hdma_tb10 = pd.read_csv(io.StringIO(data_2hdma_tb10), encoding='utf8', sep=",")
df_2hdma_tb10.head()
# Out:
#      mA   ma       eff
# 0  1100  250  1.000000
# 1  1200  350  0.988778
# 2  1400  150  0.992905
# 3   800  500  0.998985
# 4  1600  250  0.992007

# %%
# read the data as a dataframe and check first columns
df_2hdma_tb1 = pd.read_csv(io.StringIO(data_2hdma_tb1), encoding='utf8', sep=",")
df_2hdma_tb1.head()
# Out:
#      mA   ma       eff
# 0  1300  500  1.000000
# 1  1800  150  0.995298
# 2   600  350  0.991873
# 3  1100  250  0.987289
# 4  1600  350  1.000000

# %%
# plot the data
dfp_zp2hdm = df_zp2hdm.pivot("mzp", "ma", "eff").astype(float)
p_zp2hdm = sns.heatmap(dfp_zp2hdm, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb10 = df_2hdma_tb10.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb10 = sns.heatmap(dfp_2hdma_tb10, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb1 = df_2hdma_tb1.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb1 = sns.heatmap(dfp_2hdma_tb1, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %% [markdown]
# ## On special request: in 1b tag and 2b tag...

# %% [markdown]
# ### 2b-tag

# %%
data_zp2hdm = """
mzp,ma,eff
2600,300,0.942103810564
2000,600,1.0
1200,500,0.996278915128
2400,600,1.0
1800,800,0.989919040266
600,300,0.997832474071
2000,500,0.99164704729
2000,400,0.979802846817
3000,200,1.0
1800,500,1.0
3000,300,1.0
1200,600,0.998064639173
2800,600,1.0
1600,800,0.991979389977
2800,500,1.0
2200,300,0.975675894651
1800,700,0.994687958733
800,500,0.997094106783
2000,800,1.0
2800,300,1.0
2200,400,1.0
2000,700,0.989853387073
1600,600,0.989535021666
2400,700,1.0
1400,700,0.988849272002
1000,600,0.99677385761
1200,700,0.995772157268
1000,400,0.993579988563
2800,400,1.0
2600,600,1.0
3000,500,1.0
1400,500,0.990514884364
600,400,0.995718269319
1600,500,0.994322998079
1400,600,0.994976105884
400,400,0.995988781294
400,300,0.994309392925
2200,700,0.96280444824
2600,700,1.0
1400,800,0.997564174847
2200,600,1.0
800,300,0.99488111483
2200,500,1.0
2400,400,1.0
2600,400,1.0
2600,500,1.0
1000,500,0.997445713983
3000,600,1.0
"""

# %%
data_2hdma_tb10 = """
mA,ma,eff
1100,250,1.0
1200,350,1.0
1400,150,1.0
800,500,0.997919695773
1600,250,0.993346139526
1000,150,1.0
1300,500,1.0
1600,350,0.997074411256
600,350,1.0
1800,150,1.0
"""

# %%
data_2hdma_tb1 = """
mA,ma,eff
1300,500,1.0
1800,150,1.0
600,350,1.0
1100,250,0.981926308983
1600,350,1.0
800,500,1.0
1000,150,1.0
300,150,1.0
1200,350,1.0
1600,250,1.0
"""

# %%
# read the data as a dataframe
df_zp2hdm = pd.read_csv(io.StringIO(data_zp2hdm), encoding='utf8', sep=",")
df_2hdma_tb10 = pd.read_csv(io.StringIO(data_2hdma_tb10), encoding='utf8', sep=",")
df_2hdma_tb1 = pd.read_csv(io.StringIO(data_2hdma_tb1), encoding='utf8', sep=",")

# %%
# plot the data
dfp_zp2hdm = df_zp2hdm.pivot("mzp", "ma", "eff").astype(float)
p_zp2hdm = sns.heatmap(dfp_zp2hdm, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb10 = df_2hdma_tb10.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb10 = sns.heatmap(dfp_2hdma_tb10, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb1 = df_2hdma_tb1.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb1 = sns.heatmap(dfp_2hdma_tb1, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %% [markdown]
# ### 1b-tag

# %%
data_zp2hdm = """
mzp,ma,eff
2600,300,1.0
2000,600,0.986586778928
1200,500,0.988422612238
2400,600,0.988252746391
1800,800,0.983829608317
600,300,0.98559961578
2000,500,0.992737871265
2000,400,0.990370142644
3000,200,0.942376056214
1800,500,0.981200329533
3000,300,1.0
1200,600,0.989643751541
2800,600,0.967404986276
1600,800,0.990053524593
2800,500,1.0
2200,300,1.0
1800,700,0.986721157907
800,500,0.986266879501
2000,800,0.990847889717
2800,300,0.935356590685
2200,400,1.0
2000,700,0.980105390194
1600,600,0.991384041208
2400,700,0.978740133743
1400,700,0.991632037737
1000,600,0.984371074107
1200,700,0.987048761464
1000,400,0.987629183464
2800,400,0.935742943128
2600,600,1.0
3000,500,1.0
1400,500,0.99151006037
600,400,0.981817088897
1600,500,0.993758492476
1400,600,0.98384362147
400,400,0.986297712109
400,300,0.987131336154
2200,700,0.9775941468
2600,700,1.0
1400,800,0.989689519985
2200,600,0.980803222396
800,300,0.989376830761
2200,500,0.988082855413
2400,400,0.990100360166
2600,400,1.0
2600,500,0.979267702888
1000,500,0.990654367665
3000,600,1.0
"""

# %%
data_2hdma_tb10 = """
mA,ma,eff
1100,250,1.0
1200,350,0.975732999785
1400,150,0.985588815976
800,500,1.0
1600,250,0.990804477064
1000,150,1.0
1300,500,1.0
1600,350,0.992419791799
600,350,0.987523512009
1800,150,1.0
"""

# %%
data_2hdma_tb1 = """
mA,ma,eff
1300,500,1.0
1800,150,0.994253558334
600,350,0.989305699639
1100,250,0.989885372729
1600,350,1.0
800,500,0.997814149528
1000,150,1.0
300,150,1.0
1200,350,1.0
1600,250,0.995666715677
"""

# %%
# read the data as a dataframe
df_zp2hdm = pd.read_csv(io.StringIO(data_zp2hdm), encoding='utf8', sep=",")
df_2hdma_tb10 = pd.read_csv(io.StringIO(data_2hdma_tb10), encoding='utf8', sep=",")
df_2hdma_tb1 = pd.read_csv(io.StringIO(data_2hdma_tb1), encoding='utf8', sep=",")

# %%
# plot the data
dfp_zp2hdm = df_zp2hdm.pivot("mzp", "ma", "eff").astype(float)
p_zp2hdm = sns.heatmap(dfp_zp2hdm, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb10 = df_2hdma_tb10.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb10 = sns.heatmap(dfp_2hdma_tb10, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb1 = df_2hdma_tb1.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb1 = sns.heatmap(dfp_2hdma_tb1, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %% [markdown]
# ## and because it is not already enough work, also check merged

# %% [markdown]
# ### merged inclusive

# %%
data_zp2hdm = """
mzp,ma,eff
2600,300,0.985972533214
2000,600,0.989478519963
1200,500,0.990732602877
2400,600,0.988158057733
1800,800,0.989425822567
600,300,1.0
2000,500,0.985753507993
2000,400,0.989367396451
3000,200,0.990293170014
1800,500,0.985799827443
3000,300,0.989048682938
1200,600,0.993429222389
2800,600,0.989098726708
1600,800,0.989878427274
2800,500,0.990751067113
2200,300,0.987313876034
1800,700,0.987818945126
800,500,1.0
2000,800,0.988094625574
2800,300,0.989684632345
2200,400,0.989132191961
2000,700,0.988097351694
1600,600,0.991279742461
2400,700,0.988817515583
1400,700,0.990734488134
1000,600,1.0
1200,700,0.984329168515
1000,400,0.976252305754
2800,400,0.990711448228
2600,600,0.987910952155
3000,500,0.991961514153
1400,500,0.990980465287
600,400,1.0
1600,500,0.990060058358
1400,600,0.991041476547
400,400,1.0
400,300,1.0
2200,700,0.989546400026
2600,700,0.987354685165
1400,800,0.993261705827
2200,600,0.989456847302
800,300,1.0
2200,500,0.987607533891
2400,400,0.988141912757
2600,400,0.991677135668
2600,500,0.990395661825
1000,500,0.983079225702
3000,600,0.990628335666
"""

# %%
data_2hdma_tb10 = """
mA,ma,eff
1100,250,1.0
1200,350,1.0
1400,150,1.0
800,500,1.0
1600,250,1.0
1000,150,1.0
1300,500,1.0
1600,350,1.0
600,350,1.0
1800,150,1.0
"""

# %%
data_2hdma_tb1 = """
mA,ma,eff
1300,500,1.0
1800,150,1.0
600,350,1.0
1100,250,1.0
1600,350,0.984408467673
800,500,1.0
1000,150,1.0
1200,350,1.0
1600,250,0.965027889626
"""

# %%
# read the data as a dataframe
df_zp2hdm = pd.read_csv(io.StringIO(data_zp2hdm), encoding='utf8', sep=",")
df_2hdma_tb10 = pd.read_csv(io.StringIO(data_2hdma_tb10), encoding='utf8', sep=",")
df_2hdma_tb1 = pd.read_csv(io.StringIO(data_2hdma_tb1), encoding='utf8', sep=",")

# %%
# plot the data
dfp_zp2hdm = df_zp2hdm.pivot("mzp", "ma", "eff").astype(float)
p_zp2hdm = sns.heatmap(dfp_zp2hdm, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb10 = df_2hdma_tb10.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb10 = sns.heatmap(dfp_2hdma_tb10, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb1 = df_2hdma_tb1.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb1 = sns.heatmap(dfp_2hdma_tb1, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %% [markdown]
# ### merged 2b

# %%
data_zp2hdm = """
mzp,ma,eff
2600,300,0.990419301783
2000,600,0.988420955357
1200,500,0.993356524373
2400,600,0.992664037475
1800,800,0.994065985005
600,300,0.0
2000,500,0.992896043332
2000,400,0.990992857147
3000,200,0.989141677812
1800,500,0.993138267599
3000,300,0.987463501456
1200,600,0.988592131087
2800,600,0.992809607223
1600,800,0.984834740163
2800,500,0.991955573263
2200,300,0.991411011885
1800,700,0.993900165769
800,500,1.0
2000,800,0.993738173308
2800,300,0.98841361464
2200,400,0.989343448276
2000,700,0.988955630502
1600,600,0.993417156202
2400,700,0.991736454151
1400,700,0.990891603918
1000,600,1.0
1200,700,0.991828199826
1000,400,0.983468578684
2800,400,0.994951360416
2600,600,0.989903301741
3000,500,0.990669922859
1400,500,0.993129811473
600,400,0.0
1600,500,0.991017681876
1400,600,0.987438129528
400,400,1.0
400,300,1.0
2200,700,0.988867482499
2600,700,0.993126878086
1400,800,0.988209775581
2200,600,0.98396531496
800,300,1.0
2200,500,0.988729839939
2400,400,0.987647337088
2600,400,0.996933766981
2600,500,0.989689372986
1000,500,1.0
3000,600,0.991064668652
"""

# %%
data_2hdma_tb10 = """
mA,ma,eff
1100,250,1.0
1200,350,1.0
1400,150,1.0
1600,250,1.0
1000,150,1.0
1300,500,1.0
1600,350,1.0
"""

# %%
data_2hdma_tb1 = """
mA,ma,eff
1300,500,1.0
1800,150,1.0
1100,250,1.0
1600,350,0.994401684601
800,500,1.0
1000,150,1.0
1200,350,1.0
1600,250,1.0
"""

# %%
# read the data as a dataframe
df_zp2hdm = pd.read_csv(io.StringIO(data_zp2hdm), encoding='utf8', sep=",")
df_2hdma_tb10 = pd.read_csv(io.StringIO(data_2hdma_tb10), encoding='utf8', sep=",")
df_2hdma_tb1 = pd.read_csv(io.StringIO(data_2hdma_tb1), encoding='utf8', sep=",")

# %%
# plot the data
dfp_zp2hdm = df_zp2hdm.pivot("mzp", "ma", "eff").astype(float)
p_zp2hdm = sns.heatmap(dfp_zp2hdm, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb10 = df_2hdma_tb10.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb10 = sns.heatmap(dfp_2hdma_tb10, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb1 = df_2hdma_tb1.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb1 = sns.heatmap(dfp_2hdma_tb1, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %% [markdown]
# ### merged 1b

# %%
data_zp2hdm = """
mzp,ma,eff
2600,300,0.985258903529
2000,600,0.989394014847
1200,500,0.984965256315
2400,600,0.988403438531
1800,800,0.985364009116
600,300,1.0
2000,500,0.984208767382
2000,400,0.989089528689
3000,200,0.992073223359
1800,500,0.984670439546
3000,300,0.988896091628
1200,600,0.995178646745
2800,600,0.987913636694
1600,800,0.993706323211
2800,500,0.990589527864
2200,300,0.984907773613
1800,700,0.986790761957
800,500,1.0
2000,800,0.984635161459
2800,300,0.987461694015
2200,400,0.989575335435
2000,700,0.988429357246
1600,600,0.990984295025
2400,700,0.987435659947
1400,700,0.987752845815
1000,600,1.0
1200,700,0.988680331712
1000,400,0.973777577236
2800,400,0.989571579366
2600,600,0.98692870588
3000,500,0.99277976755
1400,500,0.99295126115
600,400,0.0
1600,500,0.990763399885
1400,600,0.99488506651
400,400,1.0
400,300,1.0
2200,700,0.991269736244
2600,700,0.986881057127
1400,800,1.0
2200,600,0.992529110624
800,300,1.0
2200,500,0.988810645539
2400,400,0.988915066537
2600,400,0.988520786825
2600,500,0.990945294394
1000,500,0.968567735865
3000,600,0.991368347711
"""

# %%
data_2hdma_tb10 = """
mA,ma,eff
1100,250,1.0
1200,350,1.0
800,500,1.0
1600,250,1.0
1300,500,1.0
1600,350,1.0
600,350,1.0
1800,150,1.0
"""

# %%
data_2hdma_tb1 = """
mA,ma,eff
1300,500,1.0
1800,150,1.0
600,350,1.0
1100,250,1.0
1600,350,0.975142511161
800,500,1.0
1000,150,1.0
1200,350,1.0
1600,250,0.951563632865
"""

# %%
# read the data as a dataframe
df_zp2hdm = pd.read_csv(io.StringIO(data_zp2hdm), encoding='utf8', sep=",")
df_2hdma_tb10 = pd.read_csv(io.StringIO(data_2hdma_tb10), encoding='utf8', sep=",")
df_2hdma_tb1 = pd.read_csv(io.StringIO(data_2hdma_tb1), encoding='utf8', sep=",")

# %%
# plot the data
dfp_zp2hdm = df_zp2hdm.pivot("mzp", "ma", "eff").astype(float)
p_zp2hdm = sns.heatmap(dfp_zp2hdm, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb10 = df_2hdma_tb10.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb10 = sns.heatmap(dfp_2hdma_tb10, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})

# %%
# plot the data
dfp_2hdma_tb1 = df_2hdma_tb1.pivot("mA", "ma", "eff").astype(float)
p_2hdma_tb1 = sns.heatmap(dfp_2hdma_tb1, annot=True, fmt=".3f", cmap='plasma_r', cbar_kws={'label': 'acc x eff: tight / loose jet cleaning'})
